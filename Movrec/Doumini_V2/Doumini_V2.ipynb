# %%
import pandas as pd
movies=pd.read_csv('movies.csv')

# %% [markdown]
# ### 1.数据清洗

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140502 entries, 0 to 140501
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   MOVIE_ID       140502 non-null  int64
#  1   NAME           140502 non-null  object
#  2   ALIAS          30322 non-null   object
#  3   ACTORS         82851 non-null   object
#  4   COVER          50654 non-null   object
#  5   DIRECTORS      70244 non-null   object
#  6   DOUBAN_SCORE   140502 non-null  float64
#  7   DOUBAN_VOTES   140502 non-null  float64
#  8   GENRES         136452 non-null  object
#  9   IMDB_ID        113256 non-null  object
#  10  LANGUAGES      131442 non-null  object
#  11  MINS           140502 non-null  float64
#  12  OFFICIAL_SITE  9821 non-null    object
#  13  REGIONS        136501 non-null  object
#  14  RELEASE_DATE   77687 non-null   object
#  15  SLUG           140502 non-null  object
#  16  STORYLINE      87052 non-null   object
#  17  TAGS           97398 non-null   object
#  18  YEAR           140502 non-null  float64
#  19  ACTOR_IDS      55633 non-null   object
#  20  DIRECTOR_IDS   47231 non-null   object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 22.5+ MB

# %% [markdown]
# 删除无用列并只保留评分大于6.5的电影

# %%
movies = movies.drop(
    columns=['COVER','IMDB_ID','MINS','OFFICIAL_SITE','RELEASE_DATE','SLUG','ACTOR_IDS','DIRECTOR_IDS','LANGUAGES','GENRES','ALIAS']
)
movies = movies[movies['DOUBAN_SCORE'] >= 6.5]

# %%
movies.isnull().sum()
# Out:
# MOVIE_ID           0
# NAME               0
# ACTORS          2023
# DIRECTORS       2688
# DOUBAN_SCORE       0
# DOUBAN_VOTES       0
# REGIONS            0
# STORYLINE        492
# TAGS               0
# YEAR               0
# dtype: int64

# %% [markdown]
# 筛选评分人数大于5000的电影并降序排列

# %%
movies_new = movies[(movies['DOUBAN_VOTES'] >= 5000)].sort_values(by=['DOUBAN_SCORE','DOUBAN_VOTES'], ascending=[False,False])[['MOVIE_ID','NAME','DOUBAN_SCORE','STORYLINE','TAGS','REGIONS','YEAR']]
movies_new
# Out:
#        MOVIE_ID                 NAME  DOUBAN_SCORE  \
# 56283   1291546                 霸王别姬           9.6
# 28985  24882562       悲惨世界：25周年纪念演唱会           9.6
# 8031   27121232  夏目友人帐 第六季 特别篇 铃响的残株           9.6
# 55895   1295124               辛德勒的名单           9.5
# 81761  10583098            十二怒汉（电视版）           9.5
# ...         ...                  ...           ...
# 46610   1308345                 野兽之瞳           6.5
# 19813  24743015                哭泣的男人           6.5
# 31201   4813645               橡皮轮胎杀手           6.5
# 35037   3082393                   青苔           6.5
# 25580   6129706               高校痞子田中           6.5
#
#                                                STORYLINE  \
# 56283  段小楼（张丰毅）与程蝶衣（张国荣）是一对打小一起长大的师兄弟，两人一个演生，一个饰旦，一向配...
# 28985  《悲惨世界》是由法国音乐剧作曲家克劳德-米歇尔·勋伯格和阿兰·鲍伯利（Alain Boubl...
# 8031   2017年4月番《夏目友人帐第六季》开播，作品第四卷BD公布，其中将收录TV开播特别篇《鈴鳴...
# 55895  1939年，波兰在纳粹德国的统治下，党卫军对犹太人进行了隔离统治。德国商人奥斯卡·辛德勒（连...
# 81761  This production of 'Twelve Angry Men', written...
# ...                                                  ...
# 46610  冲（吴彦祖 饰）和瞳（古天乐 饰）是同卵双胞胎，自小冲就生活在哥哥瞳的光芒之下。岂料在冲26...
# 19813  坤（张东健 饰）是一名技艺精湛的冷血杀手，效力于黑社会组织，深受上司的信赖。然而，一段不堪回...
# 31201  一望无际的荒漠旷野之上，盘桓着十多名不同身份不同年龄的普通人，他们手里各自拿着一个望远镜，透...
# 35037  丈（余文乐 饰）是香港深水区的一名放蛇警察，作为底层的警察，丈整日与一个难得见光的世界打交道...
# 25580  在位于埼玉县的某个乡下小镇，留着超级夸张爆炸头的田中广（松田翔太 饰）度过了浑浑噩噩的童年、...
#
#                                           TAGS      REGIONS    YEAR
# 56283                  经典/人性/文艺/爱情/人生/同志/剧情/文革  中国大陆 / 中国香港  1993.0
# 28985  音乐剧/悲惨世界/英国/经典/音乐/LesMisérables/2010/西区           英国  2010.0
# 8031             夏目友人帐/治愈/动漫/日本/动画/温情/日本动画/治愈系           日本  2017.0
# 55895           人性/二战/经典/斯皮尔伯格/战争/辛德勒的名单/美国/剧情           美国  1993.0
# 81761                法律/经典/人性/悬疑/美国/剧情/十二怒汉/犯罪           美国  1954.0
# ...                                        ...          ...     ...
# 46610         古天乐/吴彦祖/香港/香港电影/动作/谭耀文/2001/野兽之瞳         中国香港  2001.0
# 19813                韩国/动作/犯罪/暴力/2014/黑帮/人性/剧情           韩国  2014.0
# 31201          法国/荒诞/cult/黑色幽默/惊悚/2010/喜剧/法国电影           法国  2010.0
# 35037            余文乐/香港电影/香港/郭子健/青苔/2008/电影/爱情         中国香港  2008.0
# 25580              日本/喜剧/2012/电影/漫画改编/爱情/青春/日剧           日本  2012.0
#
# [3056 rows x 7 columns]

# %% [markdown]
# ### 2.余弦相似度模型构建

# %%
movies_new['INFO'] = (
    movies['STORYLINE'].fillna('').astype(str) + " " +
    movies['TAGS'].fillna('').astype(str) + " " +
    movies['YEAR'].fillna('').astype(str)
)
movies_new = movies_new.drop(columns=['STORYLINE','TAGS','YEAR'])

# %%
movies_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3056 entries, 56283 to 25580
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MOVIE_ID      3056 non-null   int64
#  1   NAME          3056 non-null   object
#  2   DOUBAN_SCORE  3056 non-null   float64
#  3   REGIONS       3056 non-null   object
#  4   INFO          3056 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 143.2+ KB

# %%
#添加中文分词库
import jieba
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 中文分词器
def chinese_tokenizer(text):
    return jieba.lcut(str(text))

# 如果你有停用词表就加载，没有就先传 None
stopwords = None  

cv = CountVectorizer(
    max_features=10000,
    tokenizer=chinese_tokenizer,
    stop_words=stopwords,   # 中文停用词表（如果有就传 list）
    token_pattern=None      # 必须设 None，否则 tokenizer 会被覆盖
)

vector = cv.fit_transform(movies_new['INFO'].astype(str)).toarray()

# %%
vector.shape
# Out:
# (3056, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)  #索引有些问题，之后再搞

# %%
similarity
# Out:
# array([[1.        , 0.65771603, 0.49876999, ..., 0.67715953, 0.66356774,
#         0.58010878],
#        [0.65771603, 1.        , 0.47500941, ..., 0.67187532, 0.64768715,
#         0.63835561],
#        [0.49876999, 0.47500941, 1.        , ..., 0.40292607, 0.37584955,
#         0.3505902 ],
#        ...,
#        [0.67715953, 0.67187532, 0.40292607, ..., 1.        , 0.71507264,
#         0.67728654],
#        [0.66356774, 0.64768715, 0.37584955, ..., 0.71507264, 1.        ,
#         0.7343728 ],
#        [0.58010878, 0.63835561, 0.3505902 , ..., 0.67728654, 0.7343728 ,
#         1.        ]])

# %%
movies_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3056 entries, 56283 to 25580
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MOVIE_ID      3056 non-null   int64
#  1   NAME          3056 non-null   object
#  2   DOUBAN_SCORE  3056 non-null   float64
#  3   REGIONS       3056 non-null   object
#  4   INFO          3056 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 143.2+ KB

# %%
import numpy as np

def recommand(movie_name, topk=5):
    # 找标签索引
    label_idx = movies_new.index[movies_new['NAME'] == movie_name]
    if len(label_idx) == 0:
        print("未找到该影片")
        return
    # 标签 -> 位置
    pos = movies_new.index.get_loc(label_idx[0])

    sims = similarity[pos]              # 第 pos 行的相似度
    # 取前 topk（跳过自己）
    cand = np.argsort(-sims)
    cand = cand[cand != pos][:topk]

    for j in cand:
        print(f"{movies_new.iloc[j]['NAME']} ")

# %%
recommand("霸王别姬")
# Out:
# 太极张三丰
# 夜空总有最大密度的蓝色
# 美少年之恋
# 醉·生梦死
# 水浒传之英雄本色

# %% [markdown]
# ### 后续需添加导演和时代标签等关系网
